# %%
import nibabel as nib
import numpy as np 
import os
import matplotlib.pyplot as plt

# %%
#Read the derivates/label of data_example_spinegeneric
mask = nib.load('/Users/vasudevsharma/VScode/Projects/ivadomed/data_example_spinegeneric/derivatives/labels/sub-cardiff03/anat/sub-cardiff03_T1w_seg-manual.nii.gz').get_data()
img = nib.load('/Users/vasudevsharma/VScode/Projects/ivadomed/data_example_spinegeneric/sub-cardiff03/anat/sub-cardiff03_T1w.nii.gz').get_data()
# Out:
# /Users/vasudevsharma/VScode/Projects/ivadomed/ivadomed_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#
# /Users/vasudevsharma/VScode/Projects/ivadomed/ivadomed_env/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Sanity check the shape of images and masks
print(mask.shape)
print(img.shape)
# Out:
# (460, 460, 16)
# (460, 460, 16)

# %%
#plot the image of a single channel
#Input is a 3D image of shape [Hieght, Width, Channels]

plt.imshow(img[:, :, 0])
plt.show()
plt.imshow(mask[:, :, 0])
